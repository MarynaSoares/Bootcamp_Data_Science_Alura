# %% [markdown]
# <a href="https://colab.research.google.com/github/MarynaSoares/Bootcamp_Data_Science_Alura/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np ### Serve para trabalhar arranjos e matrizes.
import pandas as pd ### Bibloteca usada para análise de dados.
from pandas_datareader import data as pdr ### Usado para acessar dados remtos, financeiros em especial.
import matplotlib.pyplot as plt ### Apresenta dados e informações matemáticas graficamente.
import seaborn as sns ### Usada na visualização de dados.
import datetime ### Usada na formatação de datas, em especial em séries temporais.
! pip install yfinance --upgrade --no-cache-dir ### pip é um sistema de gerenciamento (baixar) pacotes em Python.
import yfinance as yf ### Serve para baixar dados financeiros, origem no Yahoo Finance.
yf.pdr_override()  ### Comando de correção (atualização) do processo e se pegar dados do Yahoo Finance.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
 TAEE3 = pdr.get_data_yahoo('TAEE3.SA', start="2015-02-02")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
TAEE3.tail()
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2023-05-15  12.33  12.45  12.30  12.34      12.34   67700
# 2023-05-16  12.35  12.45  12.28  12.34      12.34   74200
# 2023-05-17  12.30  12.44  12.28  12.33      12.33   75100
# 2023-05-18  12.33  12.49  12.28  12.37      12.37  115000
# 2023-05-19   0.00  12.43  12.43  12.43      12.43       0

# %%
TAEE3.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2015-02-02  10.33333  10.33333  10.33333  10.33333    4.92474       0
# 2015-02-03  10.33333  10.33333  10.33333  10.33333    4.92474       0
# 2015-02-04  10.33333  10.33333  10.33333  10.33333    4.92474       0
# 2015-02-05  10.33333  10.33333  10.33333  10.33333    4.92474       0
# 2015-02-06  10.33333  10.33333  10.33333  10.33333    4.92474       0

# %%
SPXI11 = pdr.get_data_yahoo('SPXI11.SA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SPXI11.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2023-05-15  217.050003  218.660004  217.050003  217.210007  217.210007    5170
# 2023-05-16  217.500000  219.500000  216.899994  218.300003  218.300003    7653
# 2023-05-17  219.979996  221.000000  218.660004  220.389999  220.389999   46307
# 2023-05-18  220.600006  224.320007  220.600006  224.320007  224.320007   11236
# 2023-05-19    0.000000  225.199997  225.199997  225.199997  225.199997       0

# %%
TAEE4 = pdr.get_data_yahoo('TAEE4.SA', start="2014-04-29")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
TAEE4.head()
# Out:
#             Open  High   Low  Close  Adj Close  Volume
# Date
# 2017-05-10  12.0  12.0  12.0   12.0     6.6404     200
# 2017-05-11  12.0  12.0  12.0   12.0     6.6404       0
# 2017-05-12  12.0  12.0  12.0   12.0     6.6404       0
# 2017-05-15  12.0  12.0  12.0   12.0     6.6404       0
# 2017-05-16  12.0  12.0  12.0   12.0     6.6404       0

# %%
IVVB11 = pdr.get_data_yahoo('IVVB11.SA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
IVVB11.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2023-05-15  223.960007  224.630005  222.990005  223.500000  223.500000  583928
# 2023-05-16  223.539993  225.470001  222.589996  224.500000  224.500000  657156
# 2023-05-17  225.020004  226.699997  224.520004  226.699997  226.699997  468359
# 2023-05-18  227.029999  230.529999  227.029999  230.529999  230.529999  572029
# 2023-05-19    0.000000  231.490005  231.490005  231.490005  231.490005       0

# %% [markdown]
# TAEE3 X SPXI11

# %%
TAEE3['Close'].plot(figsize=(20,4), label = "Ações Holding TAESA (ordinárias)")
SPXI11['Close'].plot(label = "ETF SP 500")
plt.legend()

# %% [markdown]
# ALUNAS: MARYNA SOARES E MARINA CANDALARFT
